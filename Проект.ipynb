spisok = []
for i in range(len(dataparams)):
    spisok.append(dataparams[i]['title'])
import requests
import pandas as pd
from time import sleep
def bigfunction(url3):
    page2 = requests.get(url3)
    soup = BeautifulSoup(page2.text)
    urls = []
    name = []
    for n in soup.find_all('a', {'class':'link link_blue no-visited'}):
        urls.append(n.get('href'))
    for t in soup.find_all('h3', {'class':'first_child'}):
        name.append(t.text)
    def Getviews(url3):
        page0 = requests.get(url3)
        soup0 = BeautifulSoup(page0.text)
        time = soup0.find_all('div', {'class' : 'smaller'})
        time1 = [view.text for view in time]
        icon = soup0.find_all('span', {'class' : 'small'})
        icon1 = [view.text for view in icon]
        s = dict(zip(icon1, time1))
        return s
    r = []
    w = []
    z = []
    p = []
    for link in urls:
        l = Getviews(link)
        for k,v in l.items():
            if k == 'Тип проекта':
                r.append(v)
        for k,v in l.items():
            if k == 'Сроки реализации проекта':
                w.append(v)
        for k,v in l.items():
            if k == 'Количество кредитов':
                z.append(v)
        for k,v in l.items():
            if k == 'Необходимо':
                p.append(v)
        sleep(2)

    project = zip(name, urls, r, w, z, p)

    df = pd.DataFrame(project)
    df.columns = ['Название проекта', 'Ссылка', 'Тип проекта', 'Время реализации', 'Количество кредитов', 'Необходимые навыки']
    print(df)

# %%
programname = input('Введите название Вашей программы. Пример: "Политология" ')
while programname not in spisok:
    if programname == "список":
        print (*spisok, sep = '\n')
        programname = input('Введите программу')
    else:
        programname = input('Ваша программа не найдена. Попробуйте ещё раз или ознакомьтесь со списком программ, введя "список"')
if programname in spisok:
        for i in range(len(dataparams)):
            for k,v in dataparams[i].items():
                v = str(v)
                if programname in v:
                    if v == programname:
                        b = dataparams[i]['value']
                        b = str(b)
                        url3 = 'https://pf.hse.ru/?campus=51999662&education_program=' + b + '&sort=149068672'
                        bigfunction(url3)
# Out:
# Введите название Вашей программы. Пример: "Политология" список
# Анализ данных в финансах (Санкт-Петербург)
# Античность
# Арабистика: язык, словесность, культура
# Ассириология
# Библеистика и история древнего Израиля
# Бизнес-информатика (Нижний Новгород)
# Бизнес-информатика (Пермь)
# Бизнес-информатика
# Бизнес-информатика (о/з) (Нижний Новгород)
# Бизнес-информатика о/з (Пермь)
# Бухгалтерский учет, аудит и налоговое планирование (з) (Пермь)
# Бухгалтерский учет, аудит и налоговое планирование (о/з) (Пермь)
# Востоковедение (Санкт-Петербург)
# Востоковедение
# География глобальных изменений и геоинформационные технологии
# Городское планирование
# Государственное и муниципальное управление
# Гражданское и предпринимательское право (о/з) (Пермь)
# Дизайн
# Дизайн (Санкт-Петербург)
# Дизайн (Нижний Новгород)
# Дизайн (Пермь)
# Египтология
# Журналистика
# Иностранные языки и межкультурная бизнес-коммуникация (Нижний Новгород)
# Иностранные языки и межкультурная коммуникация
# ...
